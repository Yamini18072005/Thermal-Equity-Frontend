# %% [markdown]
# # Data inventory
# Inspect available inputs and document missing authoritative datasets.

# %%
from pathlib import Path
import subprocess, sys
root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
print(root)
subprocess.run([sys.executable, str(root / 'scripts' / 'project_validation.py')], check=False)
